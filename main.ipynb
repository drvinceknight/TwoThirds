# %%
import twothirds 
import random
# %matplotlib inline
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
activity = twothirds.Activity('main.csv')

# %% [markdown]
# # First game

# %% [markdown]
# Winning guess:

# %%
activity.games[0].find_winner()[-1]
# Out:
# 22

# %% [markdown]
# Winner:

# %%
activity.games[0].find_winner()[:-1]
# Out:
# ('Red',)

# %% [markdown]
# # Second game

# %% [markdown]
# Winning guess:

# %%
activity.games[1].find_winner()[-1]
# Out:
# 10

# %% [markdown]
# Winner:

# %%
activity.games[1].find_winner()[:-1]
# Out:
# ('Jill',)

# %% [markdown]
# # Plots

# %%
# %matplotlib inline
activity.analyse();
activity.distplot();
activity.pairplot();
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# # Summary

# %%
activity
# Out:
# =====================
# Game 0
# ---------------------
# 2/3rds of the average: 26.00
# Winning guess: 22
# Winner(s): ('Red',)
# =====================
# Game 1
# ---------------------
# 2/3rds of the average: 12.67
# Winning guess: 10
# Winner(s): ('Jill',)

# %% [markdown]
# # All results

# %%
activity = twothirds.Activity('data.csv')
activity.analyse();
activity.distplot();
activity.pairplot();
activity
# Out:
# =====================
# Game 0
# ---------------------
# 2/3rds of the average: 23.74
# Winning guess: 24
# Winner(s): ('Anonymous',)
# =====================
# Game 1
# ---------------------
# 2/3rds of the average: 12.31
# Winning guess: 12
# Winner(s): ('Anonymous',)

# %% [markdown]
# # Namibia 2016

# %%
activity = twothirds.Activity('data/namibia_2016.csv')
activity.analyse();
activity.distplot();
activity.pairplot();
activity
# Out:
# =====================
# Game 0
# ---------------------
# 2/3rds of the average: 27.85
# Winning guess: 26
# Winner(s): ('Anonymous',)
# =====================
# Game 1
# ---------------------
# 2/3rds of the average: 20.16
# Winning guess: 20
# Winner(s): ('Anonymous',)
