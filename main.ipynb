# %%
import twothirds 
import random

# %%
activity = twothirds.Activity('main.csv')

# %% [markdown]
# # First game

# %% [markdown]
# Winning guess:

# %%
activity.games[0].find_winner()[-1]
# Out:
# 22

# %% [markdown]
# Winner:

# %%
activity.games[0].find_winner()[:-1]
# Out:
# ('Red',)

# %% [markdown]
# # Second game

# %% [markdown]
# Winning guess:

# %%
activity.games[1].find_winner()[-1]
# Out:
# 10

# %% [markdown]
# Winner:

# %%
activity.games[1].find_winner()[:-1]
# Out:
# ('Jill',)

# %% [markdown]
# # Plots

# %%
# %matplotlib inline
activity.analyse();
activity.distplot();
activity.pairplot();

# %% [markdown]
# # Summary

# %%
activity
# Out:
# =====================
# Game 0
# ---------------------
# 2/3rds of the average: 26.00
# Winning guess: 22
# Winner(s): ('Red',)
# =====================
# Game 1
# ---------------------
# 2/3rds of the average: 12.67
# Winning guess: 10
# Winner(s): ('Jill',)

# %% [markdown]
# # All results

# %%
activity = twothirds.Activity('data.csv')
activity.analyse();
activity.distplot();
activity.pairplot();
activity
# Out:
# =====================
# Game 0
# ---------------------
# 2/3rds of the average: 23.11
# Winning guess: 23
# Winner(s): ('Anonymous',)
# =====================
# Game 1
# ---------------------
# 2/3rds of the average: 11.36
# Winning guess: 11
# Winner(s): ('Anonymous',)
